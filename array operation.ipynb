# %%
arr=[10,20,30,40,50]
for i in arr:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
arr.insert(2,25)
print(arr)
# Out:
# [10, 20, 25, 30, 40, 50]

# %%
arr.remove(25)
print(arr)
# Out:
# [10, 20, 30, 40, 50]

# %%
arr[4]=45
print(arr)
# Out:
# [10, 20, 30, 40, 45]

# %%
key=30
if key in arr:
    print('the element found')
else:
    print('Not found')
# Out:
# the element found

# %%
arr=[20,40,10,50,30]
arr.sort()
print(arr)
# Out:
# [10, 20, 30, 40, 50]

# %%
arr=[1,20,2,4,5,6]
print(arr[1])
# Out:
# 20

# %%
stack=[]
stack.append
