# %%
stack = []

while True:
    print(f"\nCurrent Stack: {stack}")
    print("1: Push | 2: Pop | 3: Peek | 4: Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        item = input("Enter value to push: ")
        stack.append(item)
        print(f"{item} pushed successfully.")

    elif choice == 2:
        if stack:
            print(f"Popped: {stack.pop()}")
        else:
            print("Stack Underflow! Empty Stack.")

    elif choice == 3:
        if stack:
            print(f"Top element: {stack[-1]}")
        else:
            print("Stack is Empty.")

    elif choice == 4:
        print("Program Ended.")
        break

    else:
        print("Enter a valid number (1-4).")
# Out:
# Current Stack: []
# 1: Push | 2: Pop | 3: Peek | 4: Exit
# Enter your choice:  1
# Enter value to push:  100
# 100 pushed successfully.
#
# Current Stack: ['100']
# 1: Push | 2: Pop | 3: Peek | 4: Exit
# Enter your choice:  200
# Enter a valid number (1-4).
#
# Current Stack: ['100']
# 1: Push | 2: Pop | 3: Peek | 4: Exit
# Enter your choice:  300
# Enter a valid number (1-4).
#
# Current Stack: ['100']
# 1: Push | 2: Pop | 3: Peek | 4: Exit
# Enter your choice:  1
# Enter value to push:  200
# 200 pushed successfully.
#
# Current Stack: ['100', '200']
# 1: Push | 2: Pop | 3: Peek | 4: Exit
# Enter your choice:  1
# Enter value to push:  300
# 300 pushed successfully.
#
# Current Stack: ['100', '200', '300']
# 1: Push | 2: Pop | 3: Peek | 4: Exit
# Enter your choice:  1
# Enter value to push:  400
# 400 pushed successfully.
#
# Current Stack: ['100', '200', '300', '400']
# 1: Push | 2: Pop | 3: Peek | 4: Exit
# Enter your choice:  2
# Popped: 400
#
# Current Stack: ['100', '200', '300']
# 1: Push | 2: Pop | 3: Peek | 4: Exit
# Enter your choice:  3
# Top element: 300
#
# Current Stack: ['100', '200', '300']
# 1: Push | 2: Pop | 3: Peek | 4: Exit
# Enter your choice:  4
# Program Ended.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class LinkedList:
    def __init__(self):
        self.head = None


    def insert_at_end(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            return

        current = self.head
        while current.next:
            current = current.next

        current.next = new_node

    def delete_value(self, key):
        current = self.head

        if current is None:
            print("List is empty! Nothing to delete.")
            return

        if current.data == key:
            self.head = current.next
            print(f"Deleted {key} from the list.")
            return

        prev = None

        while current and current.data != key:
            prev = current
            current = current.next

        if current is None:
            print(f"Value {key} not found in the list.")
            return

        prev.next = current.next
        print(f"Deleted {key} from the list.")


    def display(self):
        if self.head is None:
            print("List is Empty.")
            return

        current = self.head
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")


llist = LinkedList()

while True:
    print("\nCurrent List:")
    llist.display()

    print("\n1: Insert")
    print("2: Delete")
    print("3: Exit")

    choice = int(input("Enter choice (1-3): "))

    if choice == 1:
        val = input("Enter value to insert: ")
        llist.insert_at_end(val)

    elif choice == 2:
        val = input("Enter value to delete: ")
        llist.delete_value(val)

    elif choice == 3:
        print("Goodbye!")
        break

    else:
        print("Invalid choice!")
# Out:
# Current List:
# List is Empty.
#
# 1: Insert
# 2: Delete
# 3: Exit
# Enter choice (1-3):  1
# Enter value to insert:  10
# Current List:
# 10 -> None
#
# 1: Insert
# 2: Delete
# 3: Exit
# Enter choice (1-3):  2
# Enter value to delete:  10
# Deleted 10 from the list.
#
# Current List:
# List is Empty.
#
# 1: Insert
# 2: Delete
# 3: Exit
# Enter choice (1-3):  3
# Goodbye!
